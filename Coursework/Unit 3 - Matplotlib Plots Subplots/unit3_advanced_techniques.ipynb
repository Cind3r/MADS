# %% [markdown]
# # Graded: x of 8 correct
# 1. Line plot
# - [x] line plot x1/y1
# - [x] axis labels
# 2. Scatter plot
# - [x] scatter x2/y2
# - [x] marker size z2
# - [x] alpha = 0.5
# - [x] axis labels
# 3. Pie chart
# - [x] Correct data
# 4. Combined figure
# - [x] Correct layout
#
# Comments:

# %% [markdown]
# # Unit 3 Short Understanding - Advanced techniques
# Your answers in each cell will build off/modify the code you wrote in the previous cell, so copy and paste as necessary.

# %% [markdown]
# The following cell provides some data.

# %%
import random

num_points = 10

# line
x1 = range(num_points)
y1 = [random.randint(0, 10) for _ in range(num_points)]

# scatter
x2 = [random.randint(0, 10) + (random.randint(0, 10) * 0.1)  for _ in range(num_points**2)]
y2 = [random.randint(0, 10) + (random.randint(0, 10) * 0.1) for _ in range(num_points**2)]
z2 = [random.randint(5, 20) for _ in range(num_points**2)]

# pie
pie = 20
cake = 58
cookies = 22

# %% [markdown]
# In the cell below, correctly import Matplotlib

# %%
# Importing the necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Create a line plot with `x1` and `y1` on their respective axes. Label the x-axis `X` and y-axis `Y`.

# %%
plt.plot(x1, y1)
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# Create a scatter plot with `x2` and `y2` on their respective axes, with the size of the points set by `z2` and a transparency of 50%. Label the x-axis `X` and y-axis `Y`.

# %%
plt.scatter(x2, y2, s=z2, alpha=0.5)
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# Make a pie chart of the three categories labeled `# pie`.

# %%
plt.pie([pie, cake, cookies], labels=['Pie', 'Cake', 'Cookies'], autopct='%1.1f%%')
# plt.pie([pie, cake, cookies], labels=['Pie', 'Cake', 'Cookies'], autopct='%1.1f%%') # optional show %
# Out:
# ([<matplotlib.patches.Wedge at 0x21b15162db0>,
#   <matplotlib.patches.Wedge at 0x21b13f59fa0>,
#   <matplotlib.patches.Wedge at 0x21b140b3f50>],
#  [Text(0.8899186877588753, 0.6465637858537406, 'Pie'),
#   Text(-1.0978293989430645, 0.06906960848527927, 'Cake'),
#   Text(0.8475645040313471, -0.7011664649040888, 'Cookies')],
#  [Text(0.4854101933230228, 0.35267115592022213, '20.0%'),
#   Text(-0.598816035787126, 0.03767433190106142, '58.0%'),
#   Text(0.4623079112898256, -0.3824544354022303, '22.0%')])

# %% [markdown]
# Create subplots using a `GridSpec` that will produce the output shown (the import statement has been provided). Make sure to set the title of each subplot.
# ![example_output.png](attachment:example_output.png)

# %%
# Import gridspec
from matplotlib.gridspec import GridSpec

# Create figure and grid of subplots
fig = plt.figure(figsize=(8, 6))
grid = GridSpec(2, 2, figure=fig)

# Line Plot 
ax1 = fig.add_subplot(grid[0, 0])
ax1.plot(x1, y1)
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title('Line Plot')

# Pie Chart
ax2 = fig.add_subplot(grid[0, 1])
ax2.pie([pie, cake, cookies], labels=['Pie', 'Cake', 'Cookies'])
# ax2.pie([pie, cake, cookies], labels=['Pie', 'Cake', 'Cookies'], autopct='%1.1f%%') # optional show percentage
ax2.set_title('Pie Chart')

# Scatter Plot
ax3 = fig.add_subplot(grid[1, :])
ax3.scatter(x2, y2, s=z2, alpha=0.5)
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
ax3.set_title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')
